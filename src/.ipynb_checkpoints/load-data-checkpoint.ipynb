# %% [markdown]
# ## Script para carregar base de dados

# %% [markdown]
# ### Importação das bibliotecas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Carregando a base BCI-SSVEP

# %%
file = '../../BCI-SSVEP/Signal Database.xlsx'
data = pd.read_csv(file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-b73d233ea065> in <module>
#       1 file = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00457/BCI-SSVEP_Database_Aceves.zip'
# ----> 2 data = pd.read_csv(file, compression='infer', header=0, sep=',', quotechar='"')
#
# ...
